# %%
from graph import vars, Graph

# %%
A, B, C = vars("ABC")

g = Graph([
    B <= A,
    C <= B,
    A & C,
])
g.idc([C], [A]).display()
# Out:
# $\displaystyle \sum_{B} \big({\sum_{C} \big({P(A, B, C) P(C) \over P(B, C)}\big) P(B, C) \over P(C)}\big)$

# %%
g = Graph([
    B <= A,
    C <= B,
    A & C
])
g.idc([C], [A]).display()
# Out:
# $\displaystyle \sum_{B} \big({\sum_{C} \big({P(A, B, C) P(C) \over P(B, C)}\big) P(B, C) \over P(C)}\big)$

# %%
g.draw()
