# %%
from sherlock_py.graph import make_vars, Graph

# %%
x, y, z = make_vars("xyz")

g = Graph([
    x & y,
    z <= x,
    y <= z,
])
expression = g.idc([y], [x])

# %%
expression.display()
# Out:
# $\displaystyle \sum_{z} \big({\sum_{y} \big({P(x, z, y) P(y) \over P(z, y)}\big) P(z, y) \over P(y)}\big)$

# %%
g.draw()
